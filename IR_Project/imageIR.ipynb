# %%
# !pip install tensorflow
# Out:
# Collecting tensorflow
#   Using cached tensorflow-2.12.0-cp310-cp310-win_amd64.whl (1.9 kB)
# Collecting tensorflow-intel==2.12.0
#   Using cached tensorflow_intel-2.12.0-cp310-cp310-win_amd64.whl (272.8 MB)
# Requirement already satisfied: wrapt<1.15,>=1.11.0 in c:\users\ideapad 320\anaconda3\lib\site-packages (from tensorflow-intel==2.12.0->tensorflow) (1.14.1)
# Requirement already satisfied: setuptools in c:\users\ideapad 320\anaconda3\lib\site-packages (from tensorflow-intel==2.12.0->tensorflow) (65.6.3)
# Collecting libclang>=13.0.0
#   Downloading libclang-16.0.0-py2.py3-none-win_amd64.whl (24.4 MB)
#      -------------------------------------- 24.4/24.4 MB 969.1 kB/s eta 0:00:00
# Requirement already satisfied: typing-extensions>=3.6.6 in c:\users\ideapad 320\anaconda3\lib\site-packages (from tensorflow-intel==2.12.0->tensorflow) (4.4.0)
# Collecting tensorflow-estimator<2.13,>=2.12.0
#   Downloading tensorflow_estimator-2.12.0-py2.py3-none-any.whl (440 kB)
#      ------------------------------------ 440.7/440.7 kB 706.8 kB/s eta 0:00:00
# Requirement already satisfied: numpy<1.24,>=1.22 in c:\users\ideapad 320\anaconda3\lib\site-packages (from tensorflow-intel==2.12.0->tensorflow) (1.23.5)
# Collecting google-pasta>=0.1.1
#   Downloading google_pasta-0.2.0-py3-none-any.whl (57 kB)
#      -------------------------------------- 57.5/57.5 kB 215.7 kB/s eta 0:00:00
# Collecting keras<2.13,>=2.12.0
#   Downloading keras-2.12.0-py2.py3-none-any.whl (1.7 MB)
#      ---------------------------------------- 1.7/1.7 MB 151.4 kB/s eta 0:00:00
# Collecting protobuf!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<5.0.0dev,>=3.20.3
#   Using cached protobuf-4.23.2-cp310-abi3-win_amd64.whl (422 kB)
# Requirement already satisfied: packaging in c:\users\ideapad 320\anaconda3\lib\site-packages (from tensorflow-intel==2.12.0->tensorflow) (22.0)
# Collecting grpcio<2.0,>=1.24.3
#   Downloading grpcio-1.54.2-cp310-cp310-win_amd64.whl (4.1 MB)
#      ---------------------------------------- 4.1/4.1 MB 328.5 kB/s eta 0:00:00
# Collecting absl-py>=1.0.0
#   Downloading absl_py-1.4.0-py3-none-any.whl (126 kB)
#      ------------------------------------ 126.5/126.5 kB 240.3 kB/s eta 0:00:00
# Collecting astunparse>=1.6.0
#   Using cached astunparse-1.6.3-py2.py3-none-any.whl (12 kB)
# Collecting opt-einsum>=2.3.2
#   Downloading opt_einsum-3.3.0-py3-none-any.whl (65 kB)
#      -------------------------------------- 65.5/65.5 kB 708.3 kB/s eta 0:00:00
# Collecting tensorflow-io-gcs-filesystem>=0.23.1
#   Downloading tensorflow_io_gcs_filesystem-0.31.0-cp310-cp310-win_amd64.whl (1.5 MB)
#      ---------------------------------------- 1.5/1.5 MB 973.7 kB/s eta 0:00:00
# Collecting tensorboard<2.13,>=2.12
#   Downloading tensorboard-2.12.3-py3-none-any.whl (5.6 MB)
#      ---------------------------------------- 5.6/5.6 MB 357.4 kB/s eta 0:00:00
# Collecting jax>=0.3.15
#   Using cached jax-0.4.11.tar.gz (1.3 MB)
#   Installing build dependencies: started
#   Installing build dependencies: finished with status 'done'
#   Getting requirements to build wheel: started
#   Getting requirements to build wheel: finished with status 'done'
#   Preparing metadata (pyproject.toml): started
#   Preparing metadata (pyproject.toml): finished with status 'done'
# Collecting flatbuffers>=2.0
#   Using cached flatbuffers-23.5.26-py2.py3-none-any.whl (26 kB)
# Collecting termcolor>=1.1.0
#   Downloading termcolor-2.3.0-py3-none-any.whl (6.9 kB)
# Requirement already satisfied: h5py>=2.9.0 in c:\users\ideapad 320\anaconda3\lib\site-packages (from tensorflow-intel==2.12.0->tensorflow) (3.7.0)
# Requirement already satisfied: six>=1.12.0 in c:\users\ideapad 320\anaconda3\lib\site-packages (from tensorflow-intel==2.12.0->tensorflow) (1.16.0)
# Collecting gast<=0.4.0,>=0.2.1
#   Downloading gast-0.4.0-py3-none-any.whl (9.8 kB)
# Requirement already satisfied: wheel<1.0,>=0.23.0 in c:\users\ideapad 320\anaconda3\lib\site-packages (from astunparse>=1.6.0->tensorflow-intel==2.12.0->tensorflow) (0.38.4)
# Requirement already satisfied: scipy>=1.7 in c:\users\ideapad 320\anaconda3\lib\site-packages (from jax>=0.3.15->tensorflow-intel==2.12.0->tensorflow) (1.10.0)
# Collecting ml-dtypes>=0.1.0
#   Downloading ml_dtypes-0.1.0-cp310-cp310-win_amd64.whl (120 kB)
#      ------------------------------------ 120.4/120.4 kB 335.8 kB/s eta 0:00:00
# Requirement already satisfied: requests<3,>=2.21.0 in c:\users\ideapad 320\anaconda3\lib\site-packages (from tensorboard<2.13,>=2.12->tensorflow-intel==2.12.0->tensorflow) (2.28.1)
# Requirement already satisfied: markdown>=2.6.8 in c:\users\ideapad 320\anaconda3\lib\site-packages (from tensorboard<2.13,>=2.12->tensorflow-intel==2.12.0->tensorflow) (3.4.1)
# Collecting google-auth<3,>=1.6.3
#   Downloading google_auth-2.19.1-py2.py3-none-any.whl (181 kB)
#      ------------------------------------ 181.3/181.3 kB 295.5 kB/s eta 0:00:00
# Collecting google-auth-oauthlib<1.1,>=0.5
#   Downloading google_auth_oauthlib-1.0.0-py2.py3-none-any.whl (18 kB)
# Collecting tensorboard-data-server<0.8.0,>=0.7.0
#   Downloading tensorboard_data_server-0.7.0-py3-none-any.whl (2.4 kB)
# Requirement already satisfied: werkzeug>=1.0.1 in c:\users\ideapad 320\anaconda3\lib\site-packages (from tensorboard<2.13,>=2.12->tensorflow-intel==2.12.0->tensorflow) (2.2.2)
# Collecting cachetools<6.0,>=2.0.0
#   Downloading cachetools-5.3.1-py3-none-any.whl (9.3 kB)
# Requirement already satisfied: urllib3<2.0 in c:\users\ideapad 320\anaconda3\lib\site-packages (from google-auth<3,>=1.6.3->tensorboard<2.13,>=2.12->tensorflow-intel==2.12.0->tensorflow) (1.26.14)
# Collecting rsa<5,>=3.1.4
#   Downloading rsa-4.9-py3-none-any.whl (34 kB)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in c:\users\ideapad 320\anaconda3\lib\site-packages (from google-auth<3,>=1.6.3->tensorboard<2.13,>=2.12->tensorflow-intel==2.12.0->tensorflow) (0.2.8)
# Collecting requests-oauthlib>=0.7.0
#   Downloading requests_oauthlib-1.3.1-py2.py3-none-any.whl (23 kB)
# Requirement already satisfied: charset-normalizer<3,>=2 in c:\users\ideapad 320\anaconda3\lib\site-packages (from requests<3,>=2.21.0->tensorboard<2.13,>=2.12->tensorflow-intel==2.12.0->tensorflow) (2.0.4)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\ideapad 320\anaconda3\lib\site-packages (from requests<3,>=2.21.0->tensorboard<2.13,>=2.12->tensorflow-intel==2.12.0->tensorflow) (3.4)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\ideapad 320\anaconda3\lib\site-packages (from requests<3,>=2.21.0->tensorboard<2.13,>=2.12->tensorflow-intel==2.12.0->tensorflow) (2023.5.7)
# Requirement already satisfied: MarkupSafe>=2.1.1 in c:\users\ideapad 320\anaconda3\lib\site-packages (from werkzeug>=1.0.1->tensorboard<2.13,>=2.12->tensorflow-intel==2.12.0->tensorflow) (2.1.1)
# Requirement already satisfied: pyasn1<0.5.0,>=0.4.6 in c:\users\ideapad 320\anaconda3\lib\site-packages (from pyasn1-modules>=0.2.1->google-auth<3,>=1.6.3->tensorboard<2.13,>=2.12->tensorflow-intel==2.12.0->tensorflow) (0.4.8)
# Collecting oauthlib>=3.0.0
#   Downloading oauthlib-3.2.2-py3-none-any.whl (151 kB)
#      ------------------------------------ 151.7/151.7 kB 312.2 kB/s eta 0:00:00
# Building wheels for collected packages: jax
#   Building wheel for jax (pyproject.toml): started
#   Building wheel for jax (pyproject.toml): finished with status 'done'
#   Created wheel for jax: filename=jax-0.4.11-py3-none-any.whl size=1487992 sha256=50bb1217baa9f54e0bb88da8d54a83b0efe7f003b59d96702a11027fbe1b64b8
#   Stored in directory: c:\users\ideapad 320\appdata\local\pip\cache\wheels\60\ba\dd\b66da6df64fba82ddb4401361647a80bb117e33b1fbca4d0b5
# Successfully built jax
# Installing collected packages: libclang, flatbuffers, termcolor, tensorflow-io-gcs-filesystem, tensorflow-estimator, tensorboard-data-server, rsa, protobuf, opt-einsum, oauthlib, ml-dtypes, keras, grpcio, google-pasta, gast, cachetools, astunparse, absl-py, requests-oauthlib, jax, google-auth, google-auth-oauthlib, tensorboard, tensorflow-intel, tensorflow
# Successfully installed absl-py-1.4.0 astunparse-1.6.3 cachetools-5.3.1 flatbuffers-23.5.26 gast-0.4.0 google-auth-2.19.1 google-auth-oauthlib-1.0.0 google-pasta-0.2.0 grpcio-1.54.2 jax-0.4.11 keras-2.12.0 libclang-16.0.0 ml-dtypes-0.1.0 oauthlib-3.2.2 opt-einsum-3.3.0 protobuf-4.23.2 requests-oauthlib-1.3.1 rsa-4.9 tensorboard-2.12.3 tensorboard-data-server-0.7.0 tensorflow-2.12.0 tensorflow-estimator-2.12.0 tensorflow-intel-2.12.0 tensorflow-io-gcs-filesystem-0.31.0 termcolor-2.3.0

# %%
import numpy as np
from tensorflow.keras.datasets import fashion_mnist
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Activation,Dropout,Flatten, Conv2D, MaxPool2D
from tensorflow.keras.optimizers import SGD
from tensorflow.keras import utils
import matplotlib.pyplot as plt
np.random.seed(1671) # for reproducibility
(X_train,y_train),(X_test,y_test)=fashion_mnist.load_data()

# %%
NB_CLASSES = 10
#X_train = X_train.reshape(X_train.shape[0],-1)
print(X_train.shape)
#X_test = X_test.reshape(X_test.shape[0],-1)
print(X_test.shape)
X_train = X_train.astype('float32')
X_test = X_test.astype('float32')

NB_FEATURES = X_train.shape[1]
X_train /= 255
X_test /= 255
Y_train = utils.to_categorical(y_train, NB_CLASSES)
Y_test = utils.to_categorical(y_test, NB_CLASSES)
# Out:
# (60000, 28, 28)
# (10000, 28, 28)

# %%
labels=['T-shirt/top','Trouser','Pullover','Dress','Coat','Sandal','Shirt','Sneaker','Bag','Ankle boot']
plt.figure(figsize = (15, 15))
for i in range(20):
    plt.subplot(5, 5, i+1)
    plt.xticks([])
    plt.xlabel(labels[y_train[i]])
    plt.imshow(X_train[i].reshape(28, 28))

# %%
X_train = X_train.reshape(60000, 28, 28, 1)
X_test = X_test.reshape(10000, 28, 28, 1)
DROPOUT = 0.3
model = Sequential()
model.add(Conv2D(32, (3, 3), activation='relu', input_shape = X_train.shape[1:]))
model.add(Conv2D(32, (3, 3), activation='relu'))
model.add(MaxPool2D((2, 2), padding='same'))
model.add(Dropout(0.25))

model.add(Conv2D(64, (3, 3), activation='relu', input_shape = X_train.shape[1:]))
model.add(Conv2D(64, (3, 3), activation='relu'))
model.add(MaxPool2D((2, 2), padding='same'))
model.add(Dropout(0.25))

model.add(Flatten())
model.add(Dense(128,Activation('relu')))
model.add(Dropout(0.5))
model.add(Dense(64,Activation('relu')))

model.add(Dropout(0.5))
model.add(Dense(10,Activation('softmax')))
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d (Conv2D)             (None, 26, 26, 32)        320
#
#  conv2d_1 (Conv2D)           (None, 24, 24, 32)        9248
#
#  max_pooling2d (MaxPooling2D  (None, 12, 12, 32)       0
#  )
#
#  dropout (Dropout)           (None, 12, 12, 32)        0
#
#  conv2d_2 (Conv2D)           (None, 10, 10, 64)        18496
#
#  conv2d_3 (Conv2D)           (None, 8, 8, 64)          36928
#
#  max_pooling2d_1 (MaxPooling  (None, 4, 4, 64)         0
#  2D)
#
#  dropout_1 (Dropout)         (None, 4, 4, 64)          0
#
#  flatten (Flatten)           (None, 1024)              0
#
#  dense (Dense)               (None, 128)               131200
#
#  dropout_2 (Dropout)         (None, 128)               0
#
#  dense_1 (Dense)             (None, 64)                8256
#
#  dropout_3 (Dropout)         (None, 64)                0
#
#  dense_2 (Dense)             (None, 10)                650
#
# =================================================================
# Total params: 205,098
# Trainable params: 205,098
# Non-trainable params: 0
# _________________________________________________________________

# %%
model.compile(optimizer='adam', loss='sparse_categorical_crossentropy', metrics = ['accuracy'])
history = model.fit(X_train, y_train, batch_size = 64, epochs = 50, validation_data = (X_test, y_test))
# Out:
# Epoch 1/50
# 938/938 [==============================] - 98s 103ms/step - loss: 0.8371 - accuracy: 0.6950 - val_loss: 0.4777 - val_accuracy: 0.8239
# Epoch 2/50
# 938/938 [==============================] - 89s 95ms/step - loss: 0.5069 - accuracy: 0.8184 - val_loss: 0.3701 - val_accuracy: 0.8651
# Epoch 3/50
# 938/938 [==============================] - 87s 93ms/step - loss: 0.4292 - accuracy: 0.8525 - val_loss: 0.3258 - val_accuracy: 0.8763
# Epoch 4/50
# 938/938 [==============================] - 86s 92ms/step - loss: 0.3820 - accuracy: 0.8704 - val_loss: 0.3001 - val_accuracy: 0.8922
# Epoch 5/50
# 938/938 [==============================] - 88s 94ms/step - loss: 0.3526 - accuracy: 0.8809 - val_loss: 0.2779 - val_accuracy: 0.9010
# Epoch 6/50
# 938/938 [==============================] - 83s 89ms/step - loss: 0.3354 - accuracy: 0.8873 - val_loss: 0.2781 - val_accuracy: 0.9037
# Epoch 7/50
# 938/938 [==============================] - 84s 90ms/step - loss: 0.3187 - accuracy: 0.8913 - val_loss: 0.2585 - val_accuracy: 0.9101
# Epoch 8/50
# 938/938 [==============================] - 89s 95ms/step - loss: 0.3030 - accuracy: 0.8972 - val_loss: 0.2506 - val_accuracy: 0.9128
# Epoch 9/50
# 938/938 [==============================] - 91s 97ms/step - loss: 0.2886 - accuracy: 0.9002 - val_loss: 0.2521 - val_accuracy: 0.9078
# Epoch 10/50
# 938/938 [==============================] - 92s 98ms/step - loss: 0.2825 - accuracy: 0.9030 - val_loss: 0.2433 - val_accuracy: 0.9157
# Epoch 11/50
# 938/938 [==============================] - 91s 97ms/step - loss: 0.2714 - accuracy: 0.9058 - val_loss: 0.2406 - val_accuracy: 0.9166
# Epoch 12/50
# 938/938 [==============================] - 88s 94ms/step - loss: 0.2640 - accuracy: 0.9084 - val_loss: 0.2470 - val_accuracy: 0.9143
# Epoch 13/50
# 938/938 [==============================] - 89s 94ms/step - loss: 0.2617 - accuracy: 0.9104 - val_loss: 0.2362 - val_accuracy: 0.9155
# Epoch 14/50
# 938/938 [==============================] - 91s 97ms/step - loss: 0.2536 - accuracy: 0.9128 - val_loss: 0.2359 - val_accuracy: 0.9172
# Epoch 15/50
# 938/938 [==============================] - 92s 98ms/step - loss: 0.2532 - accuracy: 0.9111 - val_loss: 0.2361 - val_accuracy: 0.9167
# Epoch 16/50
# 938/938 [==============================] - 88s 94ms/step - loss: 0.2440 - accuracy: 0.9151 - val_loss: 0.2343 - val_accuracy: 0.9171
# Epoch 17/50
# 938/938 [==============================] - 91s 97ms/step - loss: 0.2432 - accuracy: 0.9161 - val_loss: 0.2298 - val_accuracy: 0.9206
# Epoch 18/50
# 938/938 [==============================] - 93s 99ms/step - loss: 0.2381 - accuracy: 0.9174 - val_loss: 0.2344 - val_accuracy: 0.9202
# Epoch 19/50
# 938/938 [==============================] - 93s 99ms/step - loss: 0.2350 - accuracy: 0.9208 - val_loss: 0.2315 - val_accuracy: 0.9173
# Epoch 20/50
# 938/938 [==============================] - 89s 95ms/step - loss: 0.2344 - accuracy: 0.9173 - val_loss: 0.2331 - val_accuracy: 0.9160
# Epoch 21/50
# 938/938 [==============================] - 97s 104ms/step - loss: 0.2280 - accuracy: 0.9201 - val_loss: 0.2349 - val_accuracy: 0.9203
# Epoch 22/50
# 938/938 [==============================] - 95s 101ms/step - loss: 0.2274 - accuracy: 0.9219 - val_loss: 0.2313 - val_accuracy: 0.9212
# Epoch 23/50
# 938/938 [==============================] - 92s 99ms/step - loss: 0.2268 - accuracy: 0.9203 - val_loss: 0.2307 - val_accuracy: 0.9194
# Epoch 24/50
# 938/938 [==============================] - 90s 96ms/step - loss: 0.2257 - accuracy: 0.9204 - val_loss: 0.2341 - val_accuracy: 0.9175
# Epoch 25/50
# 938/938 [==============================] - 91s 97ms/step - loss: 0.2190 - accuracy: 0.9229 - val_loss: 0.2449 - val_accuracy: 0.9175
# Epoch 26/50
# 938/938 [==============================] - 91s 97ms/step - loss: 0.2161 - accuracy: 0.9248 - val_loss: 0.2208 - val_accuracy: 0.9244
# Epoch 27/50
# 938/938 [==============================] - 96s 103ms/step - loss: 0.2147 - accuracy: 0.9244 - val_loss: 0.2316 - val_accuracy: 0.9210
# Epoch 28/50
# 938/938 [==============================] - 97s 104ms/step - loss: 0.2162 - accuracy: 0.9248 - val_loss: 0.2256 - val_accuracy: 0.9239
# Epoch 29/50
# 938/938 [==============================] - 93s 99ms/step - loss: 0.2097 - accuracy: 0.9267 - val_loss: 0.2261 - val_accuracy: 0.9248
# Epoch 30/50
# 938/938 [==============================] - 96s 102ms/step - loss: 0.2074 - accuracy: 0.9272 - val_loss: 0.2371 - val_accuracy: 0.9230
# Epoch 31/50
# 938/938 [==============================] - 93s 99ms/step - loss: 0.2108 - accuracy: 0.9269 - val_loss: 0.2339 - val_accuracy: 0.9236
# Epoch 32/50
# 938/938 [==============================] - 93s 100ms/step - loss: 0.2041 - accuracy: 0.9290 - val_loss: 0.2173 - val_accuracy: 0.9266
# Epoch 33/50
# 938/938 [==============================] - 94s 101ms/step - loss: 0.2086 - accuracy: 0.9268 - val_loss: 0.2248 - val_accuracy: 0.9231
# Epoch 34/50
# 938/938 [==============================] - 93s 99ms/step - loss: 0.2012 - accuracy: 0.9304 - val_loss: 0.2336 - val_accuracy: 0.9221
# Epoch 35/50
# 938/938 [==============================] - 94s 101ms/step - loss: 0.2040 - accuracy: 0.9290 - val_loss: 0.2314 - val_accuracy: 0.9251
# Epoch 36/50
# 938/938 [==============================] - 91s 97ms/step - loss: 0.2051 - accuracy: 0.9290 - val_loss: 0.2263 - val_accuracy: 0.9229
# Epoch 37/50
# 938/938 [==============================] - 94s 101ms/step - loss: 0.2020 - accuracy: 0.9305 - val_loss: 0.2345 - val_accuracy: 0.9234
# Epoch 38/50
# 938/938 [==============================] - 90s 96ms/step - loss: 0.1949 - accuracy: 0.9315 - val_loss: 0.2332 - val_accuracy: 0.9276
# Epoch 39/50
# 938/938 [==============================] - 92s 98ms/step - loss: 0.1963 - accuracy: 0.9325 - val_loss: 0.2237 - val_accuracy: 0.9255
# Epoch 40/50
# 938/938 [==============================] - 91s 97ms/step - loss: 0.1955 - accuracy: 0.9316 - val_loss: 0.2457 - val_accuracy: 0.9196
# Epoch 41/50
# 938/938 [==============================] - 94s 101ms/step - loss: 0.1950 - accuracy: 0.9316 - val_loss: 0.2269 - val_accuracy: 0.9236
# Epoch 42/50
# 938/938 [==============================] - 96s 103ms/step - loss: 0.1926 - accuracy: 0.9319 - val_loss: 0.2421 - val_accuracy: 0.9224
# Epoch 43/50
# 938/938 [==============================] - 92s 99ms/step - loss: 0.1920 - accuracy: 0.9331 - val_loss: 0.2382 - val_accuracy: 0.9264
# Epoch 44/50
# 938/938 [==============================] - 93s 99ms/step - loss: 0.1918 - accuracy: 0.9334 - val_loss: 0.2389 - val_accuracy: 0.9249
# Epoch 45/50
# 938/938 [==============================] - 96s 102ms/step - loss: 0.1876 - accuracy: 0.9338 - val_loss: 0.2257 - val_accuracy: 0.9251
# Epoch 46/50
# 938/938 [==============================] - 97s 103ms/step - loss: 0.1886 - accuracy: 0.9340 - val_loss: 0.2316 - val_accuracy: 0.9239
# Epoch 47/50
# 938/938 [==============================] - 95s 101ms/step - loss: 0.1923 - accuracy: 0.9338 - val_loss: 0.2382 - val_accuracy: 0.9269
# Epoch 48/50
# 938/938 [==============================] - 93s 99ms/step - loss: 0.1873 - accuracy: 0.9348 - val_loss: 0.2335 - val_accuracy: 0.9286
# Epoch 49/50
# 938/938 [==============================] - 93s 99ms/step - loss: 0.1886 - accuracy: 0.9338 - val_loss: 0.2306 - val_accuracy: 0.9227
# Epoch 50/50
# 938/938 [==============================] - 96s 103ms/step - loss: 0.1818 - accuracy: 0.9367 - val_loss: 0.2346 - val_accuracy: 0.9266

# %%
score = model.evaluate(X_test, y_test, verbose=1)
print("Test score:", score[0])
print('Test accuracy:', score[1])
# Out:
# 313/313 [==============================] - 3s 10ms/step - loss: 0.2346 - accuracy: 0.9266
# Test score: 0.23455213010311127
# Test accuracy: 0.9265999794006348

# %%
plt.title('Model Accuracy')
plt.plot( range(1, 51),history.history['accuracy'])
plt.plot( range(1, 51),history.history['val_accuracy'])
plt.xlabel('Epoch')
plt.ylabel('accuracy')
plt.legend(labels=['train','validation'])
plt.show()

plt.title('Model Loss')
plt.plot(range(1, 51),history.history['loss'])
plt.plot(range(1, 51),history.history['val_loss'])
plt.xlabel('Epoch')
plt.ylabel('loss')
plt.legend(labels=['train','validation'])
plt.show()

# %%
image_1 = X_test[10]
image = np.expand_dims(image_1, axis=0)

predictions = model.predict(image)

predicted_class = np.argmax(predictions[0])

print(f"Predicted class: {predicted_class}")


plt.xlabel(labels[predicted_class])
plt.imshow(image_1.reshape(28, 28))
# Out:
# 1/1 [==============================] - 0s 24ms/step
# Predicted class: 4
